# %%
import urllib.request as ur
import re

# %%
url = "https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/main/ch02/01_main-chapter-code/the-verdict.txt"
file_path = "the-verdict.txt"

ur.urlretrieve(url, file_path)
# Out:
# ('the-verdict.txt', <http.client.HTTPMessage at 0x7f01776423d0>)

# %%
with open(file_path, 'r', encoding="utf-8") as f:
  raw_text = f.read()

# %%
print("Total number of Characters =>", len(raw_text))
print("First Forty Characters =>", raw_text[:40])
# Out:
# Total number of Characters => 20479
# First Forty Characters => I HAD always thought Jack Gisburn rather

# %%
pattern = r'([,.:;?!()_\'"]|--|\s)'
tokens = re.split(pattern, raw_text)
tokens = [word.strip() for word in tokens if word.strip()]

# %%
print("Total Tokens =>", len(tokens))
print("Fist Thirty Tokens =>", tokens[:30])
# Out:
# Total Tokens => 4690
# Fist Thirty Tokens => ['I', 'HAD', 'always', 'thought', 'Jack', 'Gisburn', 'rather', 'a', 'cheap', 'genius', '--', 'though', 'a', 'good', 'fellow', 'enough', '--', 'so', 'it', 'was', 'no', 'great', 'surprise', 'to', 'me', 'to', 'hear', 'that', ',', 'in']

# %% [markdown]
# <div align="center">
#   <img src="attachment:5469e00a-1157-43e4-a777-99c41e852c93.png" alt="image" width="70%">
# </div>
