# %%
import torch

# %%
input_ids = torch.tensor([2, 3, 5, 1])

vocab_size = 6
output_dim = 3

# %%
torch.manual_seed(666)
embedding_layer = torch.nn.Embedding(vocab_size, output_dim)

# %%
print(embedding_layer.weight)
# Out:
# Parameter containing:
# tensor([[-0.7747,  0.7926, -0.3170],
#         [ 1.6640,  0.7148,  0.3590],
#         [-0.1242,  2.0345, -0.3479],
#         [-0.4007,  0.1841,  0.0934],
#         [ 0.3168, -0.8889,  1.1768],
#         [ 0.8074,  0.9144,  1.6259]], requires_grad=True)

# %%
print(embedding_layer(input_ids))
# Out:
# tensor([[-0.1242,  2.0345, -0.3479],
#         [-0.4007,  0.1841,  0.0934],
#         [ 0.8074,  0.9144,  1.6259],
#         [ 1.6640,  0.7148,  0.3590]], grad_fn=<EmbeddingBackward0>)

# %%
print(embedding_layer(input_ids[2]))
# Out:
# tensor([0.8074, 0.9144, 1.6259], grad_fn=<EmbeddingBackward0>)

# %% [markdown]
# <div align="center">
#   <img src="attachment:ac8710b5-fb83-482e-9a52-179d61150e06.png" alt="image" width="60%">
# </div>
