# %% [markdown]
# <div align="center">
#   <img src="attachment:67c665f7-9513-4e0d-8dcc-70c46a1cfe66.png" alt="image" width="70%">
# </div>

# %% [markdown]
# <div align="center">
#   <img src="attachment:a5afcb30-e8d8-4ae1-9519-89f5bd42a4d8.png" alt="image" width="70%">
# </div>
