# %% [markdown]
# ## **Problem With Modeling Long Sequences:**
#
# <div align="center">
#   <img src="attachment:87f09da4-ce72-4417-b811-dbaf98a1e205.png" alt="image" width="60%">
# </div>

# %% [markdown]
# ## **Solution Before LLM's:**
#
# <div align="center">
#   <img src="attachment:cde7964a-76bc-43de-bd72-6e179600e505.png" alt="image" width="60%">
# </div>

# %% [markdown]
# ## **Problem With the Encoder-Decoder Model:**
#
# <div align="center">
#   <img src="attachment:b95d739d-f241-495d-b8cb-94a46811e00f.png" alt="image" width="70%">
# </div>
