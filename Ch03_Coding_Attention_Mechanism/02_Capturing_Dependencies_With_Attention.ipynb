# %% [markdown]
# ## **General Idea of Attention in Bahdanau RNN Mechanism:**
#
# <div align="center">
#   <img src="attachment:094733ce-864b-4c8a-a6bc-516d428b2ca3.png" alt="image" width="60%">
# </div>
